# %% [markdown]
# ## a = int(input("Enter the First Number:"))
#
# n = int(input("Enter the Second Number:"))
#
# print("Operation to perform:");
# print("1. Addition");
# print("2. Subtraction");
# print("3. Multiplication");
# print("4. Division");
#
# choice = input("Enter the choice: ");
#
# if choice ==  '1' :
#     a = (a+n)
#
# if choice ==  '2' :
#     a = (a-n)
#
# if choice ==  '3' :
#     a = (a*n)
#
# if choice ==  '4' :
#     a = (a/n)
#
# if (choice=="="):
#     print("Answer = ",a)
# else:
#     print("Operation to perform:");
#     print("1. Addition");
#     print("2. Subtraction");
#     print("3. Multiplication");
#     print("4. Division");
#     choice = input("Enter next : ");
#     n = int(input("Enter next number:"))
#     if choice ==  '1' :
#         a = (a+n)
#
#     if choice ==  '2' :
#         a = (a-n)
#
#     if choice ==  '3' :
#         a = (a*n)
#
#     if choice ==  '4' :
#         a = (a/n)

# %%
a = int(input("Enter the First Number:"))
n = int(input("Enter the Second Number:"))

print("Operation to perform:"); 
print("1. Addition"); 
print("2. Subtraction"); 
print("3. Multiplication"); 
print("4. Division");

choice = input("Enter the choice: ");
if choice == '1' : 
    a = (a+n)

if choice == '2' : 
    a = (a-n)

if choice == '3' : 
    a = (a*n)

if choice == '4' : 
    a = (a/n)

if (choice=="="): 
    print("Answer = ",a) 
else:
    print("Operation to perform:"); 
    print("1. Addition"); 
    print("2. Subtraction"); 
    print("3. Multiplication"); 
    print("4. Division"); 
    choice = input("Enter choice : "); 
    n = int(input("Enter next number:")) 
    if choice == '1' :
        a = (a+n)
    if choice ==  '2' :
        a = (a-n)
    if choice ==  '3' :
        a = (a*n)
    if choice ==  '4' :
        a = (a/n)
    print(a)
